# %% [markdown]
# Example of using LinUCB on a recommendation environment with parametric actions

# %%
import os
import time

from matplotlib import pyplot as plt
import pandas as pd

from ray import tune
from ray.rllib.contrib.bandits.agents import LinUCBTrainer
from ray.rllib.contrib.bandits.agents.lin_ucb import UCB_CONFIG
from ray.rllib.contrib.bandits.envs import ParametricItemRecoEnv

# %matplotlib inline

# %%
UCB_CONFIG["env"] = ParametricItemRecoEnv

# Actual training_iterations will be 20 * timesteps_per_iteration (100 by default) = 2,000
training_iterations = 20

print("Running training for %s time steps" % training_iterations)
# Out:
# Running training for 20 time steps

# %%
start_time = time.time()

# first argument should no longer be `LinUCBTrainer`

analysis = tune.run(
    "contrib/LinUCB",
    config=UCB_CONFIG,
    stop={"training_iteration": training_iterations},
    num_samples=5,
    checkpoint_at_end=False
)

print("The trials took", time.time() - start_time, "seconds\n")
# Out:
# == Status ==<br>Memory usage on this node: 11.3/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1/4 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (4 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>PENDING </td><td>     </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>PENDING </td><td>     </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>PENDING </td><td>     </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=96684) 2020-05-18 14:37:22,503	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=96684) 2020-05-18 14:37:22,505	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=96684) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=96684)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=96685) 2020-05-18 14:37:22,503	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=96685) 2020-05-18 14:37:22,505	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=96685) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=96685)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=96684) 2020-05-18 14:37:22,534	INFO trainable.py:217 -- Getting current IP.
# (pid=96684) 2020-05-18 14:37:22,534	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=96685) 2020-05-18 14:37:22,554	INFO trainable.py:217 -- Getting current IP.
# (pid=96685) 2020-05-18 14:37:22,554	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# Result for contrib_LinUCB_ParametricItemRecoEnv_00001:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-23
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9150308836486726
#   episode_reward_mean: 0.851859908666717
#   episode_reward_min: 0.6440542894729858
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: 1a9a13e1271347808b3b3f8f58f1eb0e
#   experiment_tag: '1'
#   grad_time_ms: 1.026
#   hostname: derwen
#   info:
#     grad_time_ms: 1.026
#     learner:
#       cumulative_regret: 3.3738683388241135
#       update_latency: 0.0005648136138916016
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 974.672
#     opt_samples: 1.0
#     sample_peak_throughput: 312.91
#     sample_time_ms: 3.196
#     update_time_ms: 0.002
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.3738683388241135
#     update_latency: 0.0005648136138916016
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 974.672
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 40.4
#     ram_util_percent: 72.1
#   pid: 96684
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 312.91
#   sample_time_ms: 3.196
#   sampler_perf:
#     mean_env_wait_ms: 0.5382405649317373
#     mean_inference_ms: 1.320602870223546
#     mean_processing_ms: 1.9568381923260076
#   time_since_restore: 0.545461893081665
#   time_this_iter_s: 0.545461893081665
#   time_total_s: 0.545461893081665
#   timestamp: 1589837843
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00001'
#   update_time_ms: 0.002
# == Status ==<br>Memory usage on this node: 11.5/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4/4 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (1 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>RUNNING </td><td>                  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>RUNNING </td><td>192.168.1.65:96684</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.545462</td><td style="text-align: right;"> 100</td><td style="text-align: right;"> 0.85186</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>RUNNING </td><td>                  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>RUNNING </td><td>                  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>PENDING </td><td>                  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# </tbody>
# </table><br><br>
# Result for contrib_LinUCB_ParametricItemRecoEnv_00000:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-23
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9289324978672326
#   episode_reward_mean: 0.8778815310893654
#   episode_reward_min: 0.7292140154106406
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: 252c7cc6ac0a45969fbc2096900d757c
#   experiment_tag: '0'
#   grad_time_ms: 0.897
#   hostname: derwen
#   info:
#     grad_time_ms: 0.897
#     learner:
#       cumulative_regret: 3.596562391313603
#       update_latency: 0.00032401084899902344
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 1114.528
#     opt_samples: 1.0
#     sample_peak_throughput: 89.062
#     sample_time_ms: 11.228
#     update_time_ms: 0.002
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.596562391313603
#     update_latency: 0.00032401084899902344
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 1114.528
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 40.4
#     ram_util_percent: 72.1
#   pid: 96685
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 89.062
#   sample_time_ms: 11.228
#   sampler_perf:
#     mean_env_wait_ms: 0.5927133088064666
#     mean_inference_ms: 1.7289525211447534
#     mean_processing_ms: 2.1080545859761757
#   time_since_restore: 0.6101169586181641
#   time_this_iter_s: 0.6101169586181641
#   time_total_s: 0.6101169586181641
#   timestamp: 1589837843
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00000'
#   update_time_ms: 0.002
#
# (pid=96726) 2020-05-18 14:37:24,008	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=96726) 2020-05-18 14:37:24,010	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=96726) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=96726)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=96726) 2020-05-18 14:37:24,029	INFO trainable.py:217 -- Getting current IP.
# (pid=96726) 2020-05-18 14:37:24,029	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=96725) 2020-05-18 14:37:24,088	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=96725) 2020-05-18 14:37:24,090	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=96725) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=96725)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=96725) 2020-05-18 14:37:24,106	INFO trainable.py:217 -- Getting current IP.
# (pid=96725) 2020-05-18 14:37:24,106	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# Result for contrib_LinUCB_ParametricItemRecoEnv_00002:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-24
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9297103843659913
#   episode_reward_mean: 0.856842709886929
#   episode_reward_min: 0.6896275048584074
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: 6bd469b717f44ee9951559926acb2e0c
#   experiment_tag: '2'
#   grad_time_ms: 0.575
#   hostname: derwen
#   info:
#     grad_time_ms: 0.575
#     learner:
#       cumulative_regret: 3.090862011472475
#       update_latency: 0.0002932548522949219
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 1738.427
#     opt_samples: 1.0
#     sample_peak_throughput: 470.208
#     sample_time_ms: 2.127
#     update_time_ms: 0.002
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.090862011472475
#     update_latency: 0.0002932548522949219
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 1738.427
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 97.5
#     ram_util_percent: 72.3
#   pid: 96726
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 470.208
#   sample_time_ms: 2.127
#   sampler_perf:
#     mean_env_wait_ms: 0.4861968578678546
#     mean_inference_ms: 2.36355196131338
#     mean_processing_ms: 2.058831772001664
#   time_since_restore: 0.6874608993530273
#   time_this_iter_s: 0.6874608993530273
#   time_total_s: 0.6874608993530273
#   timestamp: 1589837844
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00002'
#   update_time_ms: 0.002
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00003:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-24
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9101113308677363
#   episode_reward_mean: 0.8555087297017744
#   episode_reward_min: 0.5938766484272477
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: 9a1b41ebca004f53aafae21f80957781
#   experiment_tag: '3'
#   grad_time_ms: 1.295
#   hostname: derwen
#   info:
#     grad_time_ms: 1.295
#     learner:
#       cumulative_regret: 3.5975899193785574
#       update_latency: 0.0003337860107421875
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 771.963
#     opt_samples: 1.0
#     sample_peak_throughput: 498.165
#     sample_time_ms: 2.007
#     update_time_ms: 0.002
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.5975899193785574
#     update_latency: 0.0003337860107421875
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 771.963
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 97.5
#     ram_util_percent: 72.3
#   pid: 96725
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 498.165
#   sample_time_ms: 2.007
#   sampler_perf:
#     mean_env_wait_ms: 0.5766991341468133
#     mean_inference_ms: 2.0379123121204934
#     mean_processing_ms: 1.8233001822292212
#   time_since_restore: 0.6804177761077881
#   time_this_iter_s: 0.6804177761077881
#   time_total_s: 0.6804177761077881
#   timestamp: 1589837844
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00003'
#   update_time_ms: 0.002
# == Status ==<br>Memory usage on this node: 11.7/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4/4 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (1 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>RUNNING </td><td>192.168.1.65:96685</td><td style="text-align: right;">    10</td><td style="text-align: right;">         4.88698</td><td style="text-align: right;">1000</td><td style="text-align: right;">0.912076</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>RUNNING </td><td>192.168.1.65:96684</td><td style="text-align: right;">    10</td><td style="text-align: right;">         4.90885</td><td style="text-align: right;">1000</td><td style="text-align: right;">0.882056</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>RUNNING </td><td>192.168.1.65:96726</td><td style="text-align: right;">     8</td><td style="text-align: right;">         4.28967</td><td style="text-align: right;"> 800</td><td style="text-align: right;">0.881022</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>RUNNING </td><td>192.168.1.65:96725</td><td style="text-align: right;">     7</td><td style="text-align: right;">         3.56639</td><td style="text-align: right;"> 700</td><td style="text-align: right;">0.888033</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>PENDING </td><td>                  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# </tbody>
# </table><br><br>
# Result for contrib_LinUCB_ParametricItemRecoEnv_00001:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-28
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9150308836486726
#   episode_reward_mean: 0.8894986398863038
#   episode_reward_min: 0.8478146736906989
#   episodes_this_iter: 100
#   episodes_total: 1100
#   experiment_id: 1a9a13e1271347808b3b3f8f58f1eb0e
#   experiment_tag: '1'
#   grad_time_ms: 1.188
#   hostname: derwen
#   info:
#     grad_time_ms: 1.188
#     learner:
#       cumulative_regret: 5.669314950716385
#       update_latency: 0.0004398822784423828
#     num_steps_sampled: 1100
#     num_steps_trained: 1100
#     opt_peak_throughput: 841.588
#     opt_samples: 1.0
#     sample_peak_throughput: 545.806
#     sample_time_ms: 1.832
#     update_time_ms: 0.002
#   iterations_since_restore: 11
#   learner:
#     cumulative_regret: 5.669314950716385
#     update_latency: 0.0004398822784423828
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 1100
#   num_steps_trained: 1100
#   off_policy_estimator: {}
#   opt_peak_throughput: 841.588
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 97.9
#     ram_util_percent: 73.0
#   pid: 96684
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 545.806
#   sample_time_ms: 1.832
#   sampler_perf:
#     mean_env_wait_ms: 0.3669495803458815
#     mean_inference_ms: 1.450218361794786
#     mean_processing_ms: 1.521144965688929
#   time_since_restore: 5.695309162139893
#   time_this_iter_s: 0.7864620685577393
#   time_total_s: 5.695309162139893
#   timestamp: 1589837848
#   timesteps_since_restore: 1100
#   timesteps_this_iter: 100
#   timesteps_total: 1100
#   training_iteration: 11
#   trial_id: '00001'
#   update_time_ms: 0.002
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00000:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-28
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9289324978672326
#   episode_reward_mean: 0.9117887120609387
#   episode_reward_min: 0.853012356197637
#   episodes_this_iter: 100
#   episodes_total: 1100
#   experiment_id: 252c7cc6ac0a45969fbc2096900d757c
#   experiment_tag: '0'
#   grad_time_ms: 0.863
#   hostname: derwen
#   info:
#     grad_time_ms: 0.863
#     learner:
#       cumulative_regret: 5.466334823330068
#       update_latency: 0.0004596710205078125
#     num_steps_sampled: 1100
#     num_steps_trained: 1100
#     opt_peak_throughput: 1158.936
#     opt_samples: 1.0
#     sample_peak_throughput: 219.878
#     sample_time_ms: 4.548
#     update_time_ms: 0.002
#   iterations_since_restore: 11
#   learner:
#     cumulative_regret: 5.466334823330068
#     update_latency: 0.0004596710205078125
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 1100
#   num_steps_trained: 1100
#   off_policy_estimator: {}
#   opt_peak_throughput: 1158.936
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 97.9
#     ram_util_percent: 73.0
#   pid: 96685
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 219.878
#   sample_time_ms: 4.548
#   sampler_perf:
#     mean_env_wait_ms: 0.41434074076168315
#     mean_inference_ms: 1.377880952230482
#     mean_processing_ms: 1.503796495165638
#   time_since_restore: 5.642566204071045
#   time_this_iter_s: 0.7555887699127197
#   time_total_s: 5.642566204071045
#   timestamp: 1589837848
#   timesteps_since_restore: 1100
#   timesteps_this_iter: 100
#   timesteps_total: 1100
#   training_iteration: 11
#   trial_id: '00000'
#   update_time_ms: 0.002
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00003:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-29
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9101113308677363
#   episode_reward_mean: 0.8887962643598816
#   episode_reward_min: 0.8156632084433868
#   episodes_this_iter: 100
#   episodes_total: 1000
#   experiment_id: 9a1b41ebca004f53aafae21f80957781
#   experiment_tag: '3'
#   grad_time_ms: 4.645
#   hostname: derwen
#   info:
#     grad_time_ms: 4.645
#     learner:
#       cumulative_regret: 5.4838471334798
#       update_latency: 0.028103351593017578
#     num_steps_sampled: 1000
#     num_steps_trained: 1000
#     opt_peak_throughput: 215.279
#     opt_samples: 1.0
#     sample_peak_throughput: 297.34
#     sample_time_ms: 3.363
#     update_time_ms: 0.002
#   iterations_since_restore: 10
#   learner:
#     cumulative_regret: 5.4838471334798
#     update_latency: 0.028103351593017578
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 1000
#   num_steps_trained: 1000
#   off_policy_estimator: {}
#   opt_peak_throughput: 215.279
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 0.0
#     ram_util_percent: 73.0
#   pid: 96725
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 297.34
#   sample_time_ms: 3.363
#   sampler_perf:
#     mean_env_wait_ms: 0.47503603802813393
#     mean_inference_ms: 1.4976881124399282
#     mean_processing_ms: 1.47674419544079
#   time_since_restore: 5.466197729110718
#   time_this_iter_s: 0.48354291915893555
#   time_total_s: 5.466197729110718
#   timestamp: 1589837849
#   timesteps_since_restore: 1000
#   timesteps_this_iter: 100
#   timesteps_total: 1000
#   training_iteration: 10
#   trial_id: '00003'
#   update_time_ms: 0.002
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00002:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-30
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9297103843659913
#   episode_reward_mean: 0.8843181011925774
#   episode_reward_min: 0.8148771612895461
#   episodes_this_iter: 100
#   episodes_total: 1100
#   experiment_id: 6bd469b717f44ee9951559926acb2e0c
#   experiment_tag: '2'
#   grad_time_ms: 0.925
#   hostname: derwen
#   info:
#     grad_time_ms: 0.925
#     learner:
#       cumulative_regret: 5.266151579267625
#       update_latency: 0.0007190704345703125
#     num_steps_sampled: 1100
#     num_steps_trained: 1100
#     opt_peak_throughput: 1081.034
#     opt_samples: 1.0
#     sample_peak_throughput: 520.314
#     sample_time_ms: 1.922
#     update_time_ms: 0.003
#   iterations_since_restore: 11
#   learner:
#     cumulative_regret: 5.266151579267625
#     update_latency: 0.0007190704345703125
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 1100
#   num_steps_trained: 1100
#   off_policy_estimator: {}
#   opt_peak_throughput: 1081.034
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 0.0
#     ram_util_percent: 73.0
#   pid: 96726
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 520.314
#   sample_time_ms: 1.922
#   sampler_perf:
#     mean_env_wait_ms: 0.3757126000011975
#     mean_inference_ms: 1.5259178847642938
#     mean_processing_ms: 1.5991398900557823
#   time_since_restore: 5.810316801071167
#   time_this_iter_s: 0.4365060329437256
#   time_total_s: 5.810316801071167
#   timestamp: 1589837850
#   timesteps_since_restore: 1100
#   timesteps_this_iter: 100
#   timesteps_total: 1100
#   training_iteration: 11
#   trial_id: '00002'
#   update_time_ms: 0.003
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00001:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-32
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9150308836486725
#   episode_reward_mean: 0.8830654724805791
#   episode_reward_min: 0.8030357134994532
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: 1a9a13e1271347808b3b3f8f58f1eb0e
#   experiment_tag: '1'
#   grad_time_ms: 1.033
#   hostname: derwen
#   info:
#     grad_time_ms: 1.033
#     learner:
#       cumulative_regret: 5.940454394136996
#       update_latency: 0.0005741119384765625
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 967.7
#     opt_samples: 1.0
#     sample_peak_throughput: 450.105
#     sample_time_ms: 2.222
#     update_time_ms: 0.003
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 5.940454394136996
#     update_latency: 0.0005741119384765625
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 967.7
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 97.3
#     ram_util_percent: 73.2
#   pid: 96684
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 450.105
#   sample_time_ms: 2.222
#   sampler_perf:
#     mean_env_wait_ms: 0.35430466395982924
#     mean_inference_ms: 1.288420197250008
#     mean_processing_ms: 1.384162354743344
#   time_since_restore: 9.58142876625061
#   time_this_iter_s: 0.3797640800476074
#   time_total_s: 9.58142876625061
#   timestamp: 1589837852
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00001'
#   update_time_ms: 0.003
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00000:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-32
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9289324978672326
#   episode_reward_mean: 0.9126913372160456
#   episode_reward_min: 0.8506961061707458
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: 252c7cc6ac0a45969fbc2096900d757c
#   experiment_tag: '0'
#   grad_time_ms: 1.837
#   hostname: derwen
#   info:
#     grad_time_ms: 1.837
#     learner:
#       cumulative_regret: 5.878006231103311
#       update_latency: 0.000698089599609375
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 544.46
#     opt_samples: 1.0
#     sample_peak_throughput: 214.688
#     sample_time_ms: 4.658
#     update_time_ms: 0.002
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 5.878006231103311
#     update_latency: 0.000698089599609375
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 544.46
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 96.4
#     ram_util_percent: 73.2
#   pid: 96685
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 214.688
#   sample_time_ms: 4.658
#   sampler_perf:
#     mean_env_wait_ms: 0.40484904528021637
#     mean_inference_ms: 1.2528140922595952
#     mean_processing_ms: 1.411951523551579
#   time_since_restore: 9.588231086730957
#   time_this_iter_s: 0.4766559600830078
#   time_total_s: 9.588231086730957
#   timestamp: 1589837852
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00000'
#   update_time_ms: 0.002
# == Status ==<br>Memory usage on this node: 11.7/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/4 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (3 RUNNING, 2 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status    </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">    20</td><td style="text-align: right;">         9.58823</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.912691</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">    20</td><td style="text-align: right;">         9.58143</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.883065</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>RUNNING   </td><td>192.168.1.65:96726</td><td style="text-align: right;">    18</td><td style="text-align: right;">         8.85072</td><td style="text-align: right;">1800</td><td style="text-align: right;">0.88164 </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>RUNNING   </td><td>192.168.1.65:96725</td><td style="text-align: right;">    18</td><td style="text-align: right;">         8.93452</td><td style="text-align: right;">1800</td><td style="text-align: right;">0.886396</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>RUNNING   </td><td>                  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# </tbody>
# </table><br><br>
# Result for contrib_LinUCB_ParametricItemRecoEnv_00002:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-34
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9297103843659913
#   episode_reward_mean: 0.8890520404991262
#   episode_reward_min: 0.8585930069025502
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: 6bd469b717f44ee9951559926acb2e0c
#   experiment_tag: '2'
#   grad_time_ms: 0.978
#   hostname: derwen
#   info:
#     grad_time_ms: 0.978
#     learner:
#       cumulative_regret: 5.731557467680181
#       update_latency: 0.0005970001220703125
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 1022.303
#     opt_samples: 1.0
#     sample_peak_throughput: 598.827
#     sample_time_ms: 1.67
#     update_time_ms: 0.002
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 5.731557467680181
#     update_latency: 0.0005970001220703125
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 1022.303
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 97.2
#     ram_util_percent: 72.5
#   pid: 96726
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 598.827
#   sample_time_ms: 1.67
#   sampler_perf:
#     mean_env_wait_ms: 0.3439721198513292
#     mean_inference_ms: 1.3058358344478884
#     mean_processing_ms: 1.3806110974969064
#   time_since_restore: 9.737197637557983
#   time_this_iter_s: 0.36525607109069824
#   time_total_s: 9.737197637557983
#   timestamp: 1589837854
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00002'
#   update_time_ms: 0.002
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00003:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-34
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9101113308677363
#   episode_reward_mean: 0.8921981530548502
#   episode_reward_min: 0.8431324525468484
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: 9a1b41ebca004f53aafae21f80957781
#   experiment_tag: '3'
#   grad_time_ms: 2.224
#   hostname: derwen
#   info:
#     grad_time_ms: 2.224
#     learner:
#       cumulative_regret: 5.879722193037287
#       update_latency: 0.0007488727569580078
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 449.608
#     opt_samples: 1.0
#     sample_peak_throughput: 328.211
#     sample_time_ms: 3.047
#     update_time_ms: 0.003
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 5.879722193037287
#     update_latency: 0.0007488727569580078
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 449.608
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf: {}
#   pid: 96725
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 328.211
#   sample_time_ms: 3.047
#   sampler_perf:
#     mean_env_wait_ms: 0.4120147091218794
#     mean_inference_ms: 1.2983341684107896
#     mean_processing_ms: 1.3295811810891427
#   time_since_restore: 9.861218690872192
#   time_this_iter_s: 0.4322078227996826
#   time_total_s: 9.861218690872192
#   timestamp: 1589837854
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00003'
#   update_time_ms: 0.003
#
# (pid=96731) 2020-05-18 14:37:39,908	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=96731) 2020-05-18 14:37:39,910	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=96731) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=96731)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=96731) 2020-05-18 14:37:39,923	INFO trainable.py:217 -- Getting current IP.
# (pid=96731) 2020-05-18 14:37:39,924	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# Result for contrib_LinUCB_ParametricItemRecoEnv_00004:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-40
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.8830322013780818
#   episode_reward_mean: 0.834635414082095
#   episode_reward_min: 0.6057654188144932
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: c69b46b102e54cb8a3e05a61a9e4adbf
#   experiment_tag: '4'
#   grad_time_ms: 0.437
#   hostname: derwen
#   info:
#     grad_time_ms: 0.437
#     learner:
#       cumulative_regret: 3.3359543314888063
#       update_latency: 0.0002238750457763672
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 2289.342
#     opt_samples: 1.0
#     sample_peak_throughput: 816.124
#     sample_time_ms: 1.225
#     update_time_ms: 0.002
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.3359543314888063
#     update_latency: 0.0002238750457763672
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 2289.342
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 93.3
#     ram_util_percent: 75.1
#   pid: 96731
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 816.124
#   sample_time_ms: 1.225
#   sampler_perf:
#     mean_env_wait_ms: 0.14738517232460557
#     mean_inference_ms: 0.44761789907323246
#     mean_processing_ms: 0.4864824880467782
#   time_since_restore: 0.16533422470092773
#   time_this_iter_s: 0.16533422470092773
#   time_total_s: 0.16533422470092773
#   timestamp: 1589837860
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00004'
#   update_time_ms: 0.002
# == Status ==<br>Memory usage on this node: 12.0/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1/4 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (1 RUNNING, 4 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status    </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">    20</td><td style="text-align: right;">        9.58823 </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.912691</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">    20</td><td style="text-align: right;">        9.58143 </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.883065</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">    20</td><td style="text-align: right;">        9.7372  </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.889052</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>TERMINATED</td><td>                  </td><td style="text-align: right;">    20</td><td style="text-align: right;">        9.86122 </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.892198</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>RUNNING   </td><td>192.168.1.65:96731</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.165334</td><td style="text-align: right;"> 100</td><td style="text-align: right;">0.834635</td></tr>
# </tbody>
# </table><br><br>
# Result for contrib_LinUCB_ParametricItemRecoEnv_00004:
#   custom_metrics: {}
#   date: 2020-05-18_14-37-43
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.8830322013780818
#   episode_reward_mean: 0.8657285134265978
#   episode_reward_min: 0.8006253135799151
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: c69b46b102e54cb8a3e05a61a9e4adbf
#   experiment_tag: '4'
#   grad_time_ms: 0.86
#   hostname: derwen
#   info:
#     grad_time_ms: 0.86
#     learner:
#       cumulative_regret: 5.415411378382347
#       update_latency: 0.0005252361297607422
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 1163.017
#     opt_samples: 1.0
#     sample_peak_throughput: 664.676
#     sample_time_ms: 1.504
#     update_time_ms: 0.002
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 5.415411378382347
#     update_latency: 0.0005252361297607422
#   node_ip: 192.168.1.65
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 1163.017
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf: {}
#   pid: 96731
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 664.676
#   sample_time_ms: 1.504
#   sampler_perf:
#     mean_env_wait_ms: 0.1523240931566687
#     mean_inference_ms: 0.4895308922077046
#     mean_processing_ms: 0.526758624815095
#   time_since_restore: 3.7111518383026123
#   time_this_iter_s: 0.20221996307373047
#   time_total_s: 3.7111518383026123
#   timestamp: 1589837863
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00004'
#   update_time_ms: 0.002
# == Status ==<br>Memory usage on this node: 12.0/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/4 CPUs, 0/0 GPUs, 0.0/3.76 GiB heap, 0.0/1.27 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (5 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status    </th><th>loc  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         9.58823</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.912691</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         9.58143</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.883065</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         9.7372 </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.889052</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         9.86122</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.892198</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         3.71115</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.865729</td></tr>
# </tbody>
# </table><br><br>
# The trials took 29.966819047927856 seconds

# %%
# Analyze cumulative regrets of the trials
frame = pd.DataFrame()
    
for key, df in analysis.trial_dataframes.items():
    frame = frame.append(df, ignore_index=True)

x = frame.groupby("num_steps_trained")[
    "learner/cumulative_regret"].aggregate(["mean", "max", "min", "std"])

# %%
plt.plot(x["mean"])
plt.fill_between(
    x.index,
    x["mean"] - x["std"],
    x["mean"] + x["std"],
    color="b",
    alpha=0.2
)

plt.title("Cumulative Regret")
plt.xlabel("Training steps")
plt.show()
