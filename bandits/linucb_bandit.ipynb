# %% [markdown]
# Example of using LinUCB on a recommendation environment with parametric actions

# %%
import os
import time

from matplotlib import pyplot as plt
import pandas as pd

from ray import tune
from ray.rllib.contrib.bandits.agents import LinUCBTrainer
from ray.rllib.contrib.bandits.agents.lin_ucb import UCB_CONFIG
from ray.rllib.contrib.bandits.envs import ParametricItemRecoEnv

# %matplotlib inline

# %%
UCB_CONFIG["env"] = ParametricItemRecoEnv

# Actual training_iterations will be 20 * timesteps_per_iteration (100 by default) = 2,000
training_iterations = 20

print("Running training for %s time steps" % training_iterations)
# Out:
# Running training for 20 time steps

# %%
start_time = time.time()

# first argument should no longer be `LinUCBTrainer`

analysis = tune.run(
    "contrib/LinUCB",
    config=UCB_CONFIG,
    stop={"training_iteration": training_iterations},
    num_samples=5,
    checkpoint_at_end=False
)

print("The trials took", time.time() - start_time, "seconds\n")
# Out:
# 2020-05-25 23:13:05,501	INFO resource_spec.py:212 -- Starting Ray with 4.25 GiB memory available for workers and up to 2.13 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-05-25 23:13:06,045	INFO services.py:1170 -- View the Ray dashboard at localhost:8266
# == Status ==<br>Memory usage on this node: 11.0/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1/4 CPUs, 0/0 GPUs, 0.0/4.25 GiB heap, 0.0/1.46 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (4 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>RUNNING </td><td>     </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>PENDING </td><td>     </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>PENDING </td><td>     </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>PENDING </td><td>     </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>PENDING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=49666) 2020-05-25 23:13:15,108	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=49666) 2020-05-25 23:13:15,110	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=49666) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=49666)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=49664) 2020-05-25 23:13:15,108	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=49664) 2020-05-25 23:13:15,110	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=49664) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=49664)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=49665) 2020-05-25 23:13:15,109	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=49665) 2020-05-25 23:13:15,111	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=49665) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=49665)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=49663) 2020-05-25 23:13:15,109	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=49663) 2020-05-25 23:13:15,111	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=49663) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=49663)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=49666) 2020-05-25 23:13:15,149	INFO trainable.py:217 -- Getting current IP.
# (pid=49666) 2020-05-25 23:13:15,149	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=49664) 2020-05-25 23:13:15,149	INFO trainable.py:217 -- Getting current IP.
# (pid=49664) 2020-05-25 23:13:15,149	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=49665) 2020-05-25 23:13:15,149	INFO trainable.py:217 -- Getting current IP.
# (pid=49665) 2020-05-25 23:13:15,149	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# (pid=49663) 2020-05-25 23:13:15,149	INFO trainable.py:217 -- Getting current IP.
# (pid=49663) 2020-05-25 23:13:15,149	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# Result for contrib_LinUCB_ParametricItemRecoEnv_00001:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-15
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.8970223913129
#   episode_reward_mean: 0.8113239513762852
#   episode_reward_min: 0.5696608795351401
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: 2cdb01c263db464eb8cb9026ac4b9e2b
#   experiment_tag: '1'
#   grad_time_ms: 0.598
#   hostname: derwen
#   info:
#     grad_time_ms: 0.598
#     learner:
#       cumulative_regret: 3.698435425657989
#       update_latency: 0.0002930164337158203
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 1671.837
#     opt_samples: 1.0
#     sample_peak_throughput: 567.365
#     sample_time_ms: 1.763
#     update_time_ms: 0.003
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.698435425657989
#     update_latency: 0.0002930164337158203
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 1671.837
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 96.7
#     ram_util_percent: 69.1
#   pid: 49664
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 567.365
#   sample_time_ms: 1.763
#   sampler_perf:
#     mean_env_wait_ms: 0.2218756345239016
#     mean_inference_ms: 0.7292067650521155
#     mean_processing_ms: 0.7529211516427522
#   time_since_restore: 0.26072120666503906
#   time_this_iter_s: 0.26072120666503906
#   time_total_s: 0.26072120666503906
#   timestamp: 1590473595
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00001'
#   update_time_ms: 0.003
# == Status ==<br>Memory usage on this node: 11.1/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4/4 CPUs, 0/0 GPUs, 0.0/4.25 GiB heap, 0.0/1.46 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (1 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>RUNNING </td><td>192.168.1.244:49664</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.260721</td><td style="text-align: right;"> 100</td><td style="text-align: right;">0.811324</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>RUNNING </td><td>                   </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>PENDING </td><td>                   </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# </tbody>
# </table><br><br>
# Result for contrib_LinUCB_ParametricItemRecoEnv_00003:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-15
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9168475858748274
#   episode_reward_mean: 0.8545420667896364
#   episode_reward_min: 0.6295353730256878
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: a92ddab211b6465cafe227bab09ea6c7
#   experiment_tag: '3'
#   grad_time_ms: 0.607
#   hostname: derwen
#   info:
#     grad_time_ms: 0.607
#     learner:
#       cumulative_regret: 3.313195284544376
#       update_latency: 0.0003807544708251953
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 1647.474
#     opt_samples: 1.0
#     sample_peak_throughput: 555.935
#     sample_time_ms: 1.799
#     update_time_ms: 0.003
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.313195284544376
#     update_latency: 0.0003807544708251953
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 1647.474
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 96.7
#     ram_util_percent: 69.1
#   pid: 49663
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 555.935
#   sample_time_ms: 1.799
#   sampler_perf:
#     mean_env_wait_ms: 0.2198242905116317
#     mean_inference_ms: 0.7734180677055131
#     mean_processing_ms: 0.7413448673663754
#   time_since_restore: 0.2777688503265381
#   time_this_iter_s: 0.2777688503265381
#   time_total_s: 0.2777688503265381
#   timestamp: 1590473595
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00003'
#   update_time_ms: 0.003
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00000:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-15
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9377491857177126
#   episode_reward_mean: 0.8545252098801492
#   episode_reward_min: 0.6650845459264028
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: 58192268a9584328a31fbbf03892164d
#   experiment_tag: '0'
#   grad_time_ms: 0.649
#   hostname: derwen
#   info:
#     grad_time_ms: 0.649
#     learner:
#       cumulative_regret: 3.084348793501926
#       update_latency: 0.0003120899200439453
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 1540.834
#     opt_samples: 1.0
#     sample_peak_throughput: 611.539
#     sample_time_ms: 1.635
#     update_time_ms: 0.002
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.084348793501926
#     update_latency: 0.0003120899200439453
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 1540.834
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 96.7
#     ram_util_percent: 69.1
#   pid: 49666
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 611.539
#   sample_time_ms: 1.635
#   sampler_perf:
#     mean_env_wait_ms: 0.2216938698645866
#     mean_inference_ms: 0.7759722152558883
#     mean_processing_ms: 0.804133934549766
#   time_since_restore: 0.2713921070098877
#   time_this_iter_s: 0.2713921070098877
#   time_total_s: 0.2713921070098877
#   timestamp: 1590473595
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00000'
#   update_time_ms: 0.002
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00002:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-15
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9298557875952485
#   episode_reward_mean: 0.8678359084709993
#   episode_reward_min: 0.6705166984028289
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: ca7f7bb453f745a3af53fd7fc1ef0533
#   experiment_tag: '2'
#   grad_time_ms: 0.801
#   hostname: derwen
#   info:
#     grad_time_ms: 0.801
#     learner:
#       cumulative_regret: 3.4040301564761424
#       update_latency: 0.0002751350402832031
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 1249.048
#     opt_samples: 1.0
#     sample_peak_throughput: 615.452
#     sample_time_ms: 1.625
#     update_time_ms: 0.002
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.4040301564761424
#     update_latency: 0.0002751350402832031
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 1249.048
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 96.7
#     ram_util_percent: 69.1
#   pid: 49665
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 615.452
#   sample_time_ms: 1.625
#   sampler_perf:
#     mean_env_wait_ms: 0.2260326158882368
#     mean_inference_ms: 0.8383198539809428
#     mean_processing_ms: 0.8151177132483752
#   time_since_restore: 0.29471707344055176
#   time_this_iter_s: 0.29471707344055176
#   time_total_s: 0.29471707344055176
#   timestamp: 1590473595
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00002'
#   update_time_ms: 0.002
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00001:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-20
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.8970223913129
#   episode_reward_mean: 0.848172483882254
#   episode_reward_min: 0.722178795911163
#   episodes_this_iter: 100
#   episodes_total: 1700
#   experiment_id: 2cdb01c263db464eb8cb9026ac4b9e2b
#   experiment_tag: '1'
#   grad_time_ms: 1.275
#   hostname: derwen
#   info:
#     grad_time_ms: 1.275
#     learner:
#       cumulative_regret: 5.277426269241023
#       update_latency: 0.0005750656127929688
#     num_steps_sampled: 1700
#     num_steps_trained: 1700
#     opt_peak_throughput: 784.143
#     opt_samples: 1.0
#     sample_peak_throughput: 434.9
#     sample_time_ms: 2.299
#     update_time_ms: 0.003
#   iterations_since_restore: 17
#   learner:
#     cumulative_regret: 5.277426269241023
#     update_latency: 0.0005750656127929688
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 1700
#   num_steps_trained: 1700
#   off_policy_estimator: {}
#   opt_peak_throughput: 784.143
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf: {}
#   pid: 49664
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 434.9
#   sample_time_ms: 2.299
#   sampler_perf:
#     mean_env_wait_ms: 0.24060709626446194
#     mean_inference_ms: 0.8068809363507019
#     mean_processing_ms: 0.8874317956349209
#   time_since_restore: 5.142775535583496
#   time_this_iter_s: 0.3091390132904053
#   time_total_s: 5.142775535583496
#   timestamp: 1590473600
#   timesteps_since_restore: 1700
#   timesteps_this_iter: 100
#   timesteps_total: 1700
#   training_iteration: 17
#   trial_id: '00001'
#   update_time_ms: 0.003
# == Status ==<br>Memory usage on this node: 11.1/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 4/4 CPUs, 0/0 GPUs, 0.0/4.25 GiB heap, 0.0/1.46 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (1 PENDING, 4 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status  </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>RUNNING </td><td>192.168.1.244:49666</td><td style="text-align: right;">    16</td><td style="text-align: right;">         4.8557 </td><td style="text-align: right;">1600</td><td style="text-align: right;">0.868163</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>RUNNING </td><td>192.168.1.244:49664</td><td style="text-align: right;">    17</td><td style="text-align: right;">         5.14278</td><td style="text-align: right;">1700</td><td style="text-align: right;">0.848172</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>RUNNING </td><td>192.168.1.244:49665</td><td style="text-align: right;">    16</td><td style="text-align: right;">         4.77215</td><td style="text-align: right;">1600</td><td style="text-align: right;">0.900388</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>RUNNING </td><td>192.168.1.244:49663</td><td style="text-align: right;">    16</td><td style="text-align: right;">         4.84544</td><td style="text-align: right;">1600</td><td style="text-align: right;">0.881864</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>PENDING </td><td>                   </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">        </td></tr>
# </tbody>
# </table><br><br>
# Result for contrib_LinUCB_ParametricItemRecoEnv_00002:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-20
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9298557875952485
#   episode_reward_mean: 0.8981793443075496
#   episode_reward_min: 0.8591959998592527
#   episodes_this_iter: 100
#   episodes_total: 1700
#   experiment_id: ca7f7bb453f745a3af53fd7fc1ef0533
#   experiment_tag: '2'
#   grad_time_ms: 1.126
#   hostname: derwen
#   info:
#     grad_time_ms: 1.126
#     learner:
#       cumulative_regret: 6.187838322572264
#       update_latency: 0.0005519390106201172
#     num_steps_sampled: 1700
#     num_steps_trained: 1700
#     opt_peak_throughput: 887.796
#     opt_samples: 1.0
#     sample_peak_throughput: 466.827
#     sample_time_ms: 2.142
#     update_time_ms: 0.002
#   iterations_since_restore: 17
#   learner:
#     cumulative_regret: 6.187838322572264
#     update_latency: 0.0005519390106201172
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 1700
#   num_steps_trained: 1700
#   off_policy_estimator: {}
#   opt_peak_throughput: 887.796
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf: {}
#   pid: 49665
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 466.827
#   sample_time_ms: 2.142
#   sampler_perf:
#     mean_env_wait_ms: 0.23234920737184114
#     mean_inference_ms: 0.7743393933331523
#     mean_processing_ms: 0.8410797758287436
#   time_since_restore: 5.0776238441467285
#   time_this_iter_s: 0.30547404289245605
#   time_total_s: 5.0776238441467285
#   timestamp: 1590473600
#   timesteps_since_restore: 1700
#   timesteps_this_iter: 100
#   timesteps_total: 1700
#   training_iteration: 17
#   trial_id: '00002'
#   update_time_ms: 0.002
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00003:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-20
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9168475858748274
#   episode_reward_mean: 0.8848624653042667
#   episode_reward_min: 0.7816820777662905
#   episodes_this_iter: 100
#   episodes_total: 1700
#   experiment_id: a92ddab211b6465cafe227bab09ea6c7
#   experiment_tag: '3'
#   grad_time_ms: 1.397
#   hostname: derwen
#   info:
#     grad_time_ms: 1.397
#     learner:
#       cumulative_regret: 5.692120012122651
#       update_latency: 0.0005130767822265625
#     num_steps_sampled: 1700
#     num_steps_trained: 1700
#     opt_peak_throughput: 715.629
#     opt_samples: 1.0
#     sample_peak_throughput: 526.837
#     sample_time_ms: 1.898
#     update_time_ms: 0.005
#   iterations_since_restore: 17
#   learner:
#     cumulative_regret: 5.692120012122651
#     update_latency: 0.0005130767822265625
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 1700
#   num_steps_trained: 1700
#   off_policy_estimator: {}
#   opt_peak_throughput: 715.629
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf: {}
#   pid: 49663
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 526.837
#   sample_time_ms: 1.898
#   sampler_perf:
#     mean_env_wait_ms: 0.24122872260092
#     mean_inference_ms: 0.8094201432754545
#     mean_processing_ms: 0.8690324970583998
#   time_since_restore: 5.190964698791504
#   time_this_iter_s: 0.34552907943725586
#   time_total_s: 5.190964698791504
#   timestamp: 1590473600
#   timesteps_since_restore: 1700
#   timesteps_this_iter: 100
#   timesteps_total: 1700
#   training_iteration: 17
#   trial_id: '00003'
#   update_time_ms: 0.005
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00000:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-20
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9377491857177126
#   episode_reward_mean: 0.8725083233808291
#   episode_reward_min: 0.7972760847173637
#   episodes_this_iter: 100
#   episodes_total: 1700
#   experiment_id: 58192268a9584328a31fbbf03892164d
#   experiment_tag: '0'
#   grad_time_ms: 1.305
#   hostname: derwen
#   info:
#     grad_time_ms: 1.305
#     learner:
#       cumulative_regret: 5.736291020989863
#       update_latency: 0.0006048679351806641
#     num_steps_sampled: 1700
#     num_steps_trained: 1700
#     opt_peak_throughput: 766.041
#     opt_samples: 1.0
#     sample_peak_throughput: 440.208
#     sample_time_ms: 2.272
#     update_time_ms: 0.003
#   iterations_since_restore: 17
#   learner:
#     cumulative_regret: 5.736291020989863
#     update_latency: 0.0006048679351806641
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 1700
#   num_steps_trained: 1700
#   off_policy_estimator: {}
#   opt_peak_throughput: 766.041
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf: {}
#   pid: 49666
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 440.208
#   sample_time_ms: 2.272
#   sampler_perf:
#     mean_env_wait_ms: 0.2516053270971264
#     mean_inference_ms: 0.7936306941656419
#     mean_processing_ms: 0.9103560013185172
#   time_since_restore: 5.2169458866119385
#   time_this_iter_s: 0.36124610900878906
#   time_total_s: 5.2169458866119385
#   timestamp: 1590473600
#   timesteps_since_restore: 1700
#   timesteps_this_iter: 100
#   timesteps_total: 1700
#   training_iteration: 17
#   trial_id: '00000'
#   update_time_ms: 0.003
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00001:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-21
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.8970223913129
#   episode_reward_mean: 0.8427217307226071
#   episode_reward_min: 0.7366241529993054
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: 2cdb01c263db464eb8cb9026ac4b9e2b
#   experiment_tag: '1'
#   grad_time_ms: 1.299
#   hostname: derwen
#   info:
#     grad_time_ms: 1.299
#     learner:
#       cumulative_regret: 5.351980491696584
#       update_latency: 0.0005810260772705078
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 769.823
#     opt_samples: 1.0
#     sample_peak_throughput: 475.593
#     sample_time_ms: 2.103
#     update_time_ms: 0.003
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 5.351980491696584
#     update_latency: 0.0005810260772705078
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 769.823
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 100.0
#     ram_util_percent: 69.2
#   pid: 49664
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 475.593
#   sample_time_ms: 2.103
#   sampler_perf:
#     mean_env_wait_ms: 0.23856644389749707
#     mean_inference_ms: 0.8063852518930963
#     mean_processing_ms: 0.8795029041112992
#   time_since_restore: 6.082367420196533
#   time_this_iter_s: 0.3043549060821533
#   time_total_s: 6.082367420196533
#   timestamp: 1590473601
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00001'
#   update_time_ms: 0.003
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00002:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-21
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9298557875952485
#   episode_reward_mean: 0.9038132443877502
#   episode_reward_min: 0.8434026609527132
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: ca7f7bb453f745a3af53fd7fc1ef0533
#   experiment_tag: '2'
#   grad_time_ms: 3.525
#   hostname: derwen
#   info:
#     grad_time_ms: 3.525
#     learner:
#       cumulative_regret: 6.434065733791271
#       update_latency: 0.0007047653198242188
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 283.675
#     opt_samples: 1.0
#     sample_peak_throughput: 386.868
#     sample_time_ms: 2.585
#     update_time_ms: 0.003
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 6.434065733791271
#     update_latency: 0.0007047653198242188
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 283.675
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 100.0
#     ram_util_percent: 69.2
#   pid: 49665
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 386.868
#   sample_time_ms: 2.585
#   sampler_perf:
#     mean_env_wait_ms: 0.2350540294580492
#     mean_inference_ms: 0.7748603820800781
#     mean_processing_ms: 0.8509769134673997
#   time_since_restore: 6.0909998416900635
#   time_this_iter_s: 0.38156795501708984
#   time_total_s: 6.0909998416900635
#   timestamp: 1590473601
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00002'
#   update_time_ms: 0.003
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00000:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-21
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9377491857177126
#   episode_reward_mean: 0.882335104449198
#   episode_reward_min: 0.8028171559981983
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: 58192268a9584328a31fbbf03892164d
#   experiment_tag: '0'
#   grad_time_ms: 2.03
#   hostname: derwen
#   info:
#     grad_time_ms: 2.03
#     learner:
#       cumulative_regret: 5.835975257390917
#       update_latency: 0.0006511211395263672
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 492.625
#     opt_samples: 1.0
#     sample_peak_throughput: 300.697
#     sample_time_ms: 3.326
#     update_time_ms: 0.002
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 5.835975257390917
#     update_latency: 0.0006511211395263672
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 492.625
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 100.0
#     ram_util_percent: 69.2
#   pid: 49666
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 300.697
#   sample_time_ms: 3.326
#   sampler_perf:
#     mean_env_wait_ms: 0.24967405690007768
#     mean_inference_ms: 0.7910235174771013
#     mean_processing_ms: 0.9073822692535568
#   time_since_restore: 6.191644906997681
#   time_this_iter_s: 0.39319801330566406
#   time_total_s: 6.191644906997681
#   timestamp: 1590473601
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00000'
#   update_time_ms: 0.002
#
# Result for contrib_LinUCB_ParametricItemRecoEnv_00003:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-21
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9168475858748274
#   episode_reward_mean: 0.8871297896585111
#   episode_reward_min: 0.8277649290833342
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: a92ddab211b6465cafe227bab09ea6c7
#   experiment_tag: '3'
#   grad_time_ms: 1.207
#   hostname: derwen
#   info:
#     grad_time_ms: 1.207
#     learner:
#       cumulative_regret: 5.788054436724449
#       update_latency: 0.0005469322204589844
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 828.275
#     opt_samples: 1.0
#     sample_peak_throughput: 471.387
#     sample_time_ms: 2.121
#     update_time_ms: 0.003
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 5.788054436724449
#     update_latency: 0.0005469322204589844
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 828.275
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 99.6
#     ram_util_percent: 69.2
#   pid: 49663
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 471.387
#   sample_time_ms: 2.121
#   sampler_perf:
#     mean_env_wait_ms: 0.24684687246983197
#     mean_inference_ms: 0.8254167975216495
#     mean_processing_ms: 0.8779145192647206
#   time_since_restore: 6.278926134109497
#   time_this_iter_s: 0.44644784927368164
#   time_total_s: 6.278926134109497
#   timestamp: 1590473601
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00003'
#   update_time_ms: 0.003
#
# (pid=49670) 2020-05-25 23:13:26,719	INFO trainer.py:421 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=49670) 2020-05-25 23:13:26,721	INFO trainer.py:580 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=49670) /opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=49670)   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# (pid=49670) 2020-05-25 23:13:26,732	INFO trainable.py:217 -- Getting current IP.
# (pid=49670) 2020-05-25 23:13:26,732	WARNING util.py:37 -- Install gputil for GPU system monitoring.
# Result for contrib_LinUCB_ParametricItemRecoEnv_00004:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-26
#   done: false
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9438930392488194
#   episode_reward_mean: 0.8723102456646203
#   episode_reward_min: 0.7436367848137744
#   episodes_this_iter: 100
#   episodes_total: 100
#   experiment_id: c0602f297a82437d9208f407ccf2d17e
#   experiment_tag: '4'
#   grad_time_ms: 0.475
#   hostname: derwen
#   info:
#     grad_time_ms: 0.475
#     learner:
#       cumulative_regret: 3.853050725366764
#       update_latency: 0.0003027915954589844
#     num_steps_sampled: 100
#     num_steps_trained: 100
#     opt_peak_throughput: 2103.884
#     opt_samples: 1.0
#     sample_peak_throughput: 686.893
#     sample_time_ms: 1.456
#     update_time_ms: 0.002
#   iterations_since_restore: 1
#   learner:
#     cumulative_regret: 3.853050725366764
#     update_latency: 0.0003027915954589844
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 100
#   num_steps_trained: 100
#   off_policy_estimator: {}
#   opt_peak_throughput: 2103.884
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 86.9
#     ram_util_percent: 70.6
#   pid: 49670
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 686.893
#   sample_time_ms: 1.456
#   sampler_perf:
#     mean_env_wait_ms: 0.16199716246954285
#     mean_inference_ms: 0.5361939420794497
#     mean_processing_ms: 0.5629227893187266
#   time_since_restore: 0.19358325004577637
#   time_this_iter_s: 0.19358325004577637
#   time_total_s: 0.19358325004577637
#   timestamp: 1590473606
#   timesteps_since_restore: 100
#   timesteps_this_iter: 100
#   timesteps_total: 100
#   training_iteration: 1
#   trial_id: '00004'
#   update_time_ms: 0.002
# == Status ==<br>Memory usage on this node: 11.3/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1/4 CPUs, 0/0 GPUs, 0.0/4.25 GiB heap, 0.0/1.46 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (1 RUNNING, 4 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status    </th><th>loc                </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">    20</td><td style="text-align: right;">        6.19164 </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.882335</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">    20</td><td style="text-align: right;">        6.08237 </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.842722</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">    20</td><td style="text-align: right;">        6.091   </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.903813</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>TERMINATED</td><td>                   </td><td style="text-align: right;">    20</td><td style="text-align: right;">        6.27893 </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.88713 </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>RUNNING   </td><td>192.168.1.244:49670</td><td style="text-align: right;">     1</td><td style="text-align: right;">        0.193583</td><td style="text-align: right;"> 100</td><td style="text-align: right;">0.87231 </td></tr>
# </tbody>
# </table><br><br>
# Result for contrib_LinUCB_ParametricItemRecoEnv_00004:
#   custom_metrics: {}
#   date: 2020-05-25_23-13-30
#   done: true
#   episode_len_mean: 1.0
#   episode_reward_max: 0.9438930392488194
#   episode_reward_mean: 0.9081171455286549
#   episode_reward_min: 0.8512483961435646
#   episodes_this_iter: 100
#   episodes_total: 2000
#   experiment_id: c0602f297a82437d9208f407ccf2d17e
#   experiment_tag: '4'
#   grad_time_ms: 0.513
#   hostname: derwen
#   info:
#     grad_time_ms: 0.513
#     learner:
#       cumulative_regret: 6.754230388694926
#       update_latency: 0.0005540847778320312
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     opt_peak_throughput: 1951.111
#     opt_samples: 1.0
#     sample_peak_throughput: 936.333
#     sample_time_ms: 1.068
#     update_time_ms: 0.001
#   iterations_since_restore: 20
#   learner:
#     cumulative_regret: 6.754230388694926
#     update_latency: 0.0005540847778320312
#   node_ip: 192.168.1.244
#   num_healthy_workers: 0
#   num_steps_sampled: 2000
#   num_steps_trained: 2000
#   off_policy_estimator: {}
#   opt_peak_throughput: 1951.111
#   opt_samples: 1.0
#   optimizer_steps_this_iter: 100
#   perf:
#     cpu_util_percent: 45.2
#     ram_util_percent: 70.7
#   pid: 49670
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sample_peak_throughput: 936.333
#   sample_time_ms: 1.068
#   sampler_perf:
#     mean_env_wait_ms: 0.14283727372306276
#     mean_inference_ms: 0.4586932779490382
#     mean_processing_ms: 0.4798584375186065
#   time_since_restore: 3.467115640640259
#   time_this_iter_s: 0.1777198314666748
#   time_total_s: 3.467115640640259
#   timestamp: 1590473610
#   timesteps_since_restore: 2000
#   timesteps_this_iter: 100
#   timesteps_total: 2000
#   training_iteration: 20
#   trial_id: '00004'
#   update_time_ms: 0.001
# == Status ==<br>Memory usage on this node: 11.3/16.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/4 CPUs, 0/0 GPUs, 0.0/4.25 GiB heap, 0.0/1.46 GiB objects<br>Result logdir: /Users/paco/ray_results/contrib/LinUCB<br>Number of trials: 5 (5 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                                </th><th>status    </th><th>loc  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00000</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.19164</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.882335</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00001</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.08237</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.842722</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00002</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.091  </td><td style="text-align: right;">2000</td><td style="text-align: right;">0.903813</td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00003</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         6.27893</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.88713 </td></tr>
# <tr><td>contrib_LinUCB_ParametricItemRecoEnv_00004</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">    20</td><td style="text-align: right;">         3.46712</td><td style="text-align: right;">2000</td><td style="text-align: right;">0.908117</td></tr>
# </tbody>
# </table><br><br>
# The trials took 25.044007062911987 seconds

# %%
# Analyze cumulative regrets of the trials
frame = pd.DataFrame()
    
for key, df in analysis.trial_dataframes.items():
    frame = frame.append(df, ignore_index=True)

x = frame.groupby("num_steps_trained")[
    "learner/cumulative_regret"].aggregate(["mean", "max", "min", "std"])

# %%
x
# Out:
#                        mean       max       min       std
# num_steps_trained
# 100                3.470612  3.853051  3.084349  0.306829
# 200                4.130505  4.592445  3.673251  0.327513
# 300                4.452673  4.993966  3.909130  0.384819
# 400                4.689579  5.133438  4.161684  0.359921
# 500                4.868538  5.404188  4.410164  0.377323
# 600                5.007850  5.575668  4.629078  0.390246
# 700                5.110475  5.676078  4.705434  0.382114
# 800                5.237107  5.832398  4.835900  0.392057
# 900                5.340498  5.902042  4.891298  0.388214
# 1000               5.426005  6.013542  4.949449  0.405791
# 1100               5.523487  6.095201  5.103194  0.382022
# 1200               5.600829  6.222678  5.105483  0.430440
# 1300               5.647506  6.234782  5.114410  0.440133
# 1400               5.706731  6.283335  5.176823  0.435236
# 1500               5.774339  6.409991  5.203983  0.466583
# 1600               5.818421  6.431364  5.228431  0.468926
# 1700               5.870702  6.459835  5.277426  0.460865
# 1800               5.919930  6.543776  5.282488  0.494838
# 1900               5.975383  6.636329  5.307670  0.529479
# 2000               6.032861  6.754230  5.351980  0.557591

# %%
plt.plot(x["mean"])
plt.fill_between(
    x.index,
    x["mean"] - x["std"],
    x["mean"] + x["std"],
    color="b",
    alpha=0.2
)

plt.title("Cumulative Regret")
plt.xlabel("Training steps")
plt.show()
